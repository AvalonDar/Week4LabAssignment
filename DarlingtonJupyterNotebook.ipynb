# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Avalon Darlington**
# Current Occupation Imagery Analyst

# %% [markdown]
# *I am interested in data science because I see a trend of data being the most reliable ways to make sound business decisions across so many different fields. There is so much data out there, and if used effectively it can really change the way the world operates and I want to be part of that.*

# %% [markdown]
# ### Cell 5 is supposed to add 10 plus 10

# %%
10+10

# %% [markdown]
# - bullet list one
# - bullet list two
# - bullet list three
#
# ~~striketrough~~
#
# <http://www.coursera.org>
